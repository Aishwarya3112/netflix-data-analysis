# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Ashwariya_AIML_1002.pdf',
#  'Colab Notebooks',
#  '403-Div-B.gsheet',
#  'Lab_1.pkt',
#  'CN physical layer (1).pdf',
#  'CN physical layer.pdf',
#  'CN physical layer (1).pptx',
#  'CN physical layer.pptx',
#  'Test responses sheet.gsheet',
#  'Lab_2.pkt',
#  'Lab4.pkt',
#  'RAZORPAY.pdf',
#  'Lab-6.pkt',
#  'LAb-7.pkt',
#  'Lab-8.pkt',
#  'Screenshot 2026-03-19 000404.png',
#  'Screenshot 2026-03-19 002705 (1).png',
#  'Screenshot 2026-03-19 002705.png',
#  'Screenshot 2026-03-19 003344.png',
#  'Screenshot 2026-03-19 005453.png',
#  'Screenshot 2026-03-19 131400.png',
#  'Lab-3.pkt',
#  'Screenshot 2026-03-19 222206.png',
#  'Screenshot 2026-03-19 222817.png',
#  'Lab-5.pkt',
#  'Screenshot 2026-03-20 002401.png',
#  'Screenshot 2026-03-20 003620.png',
#  'ML-403.gsheet',
#  'Bone-Fracture-Detection',
#  'Sustainable_Cloud_Report.pdf',
#  'Aishwarya_Sharma_Resume_Product_AI_Final (1).pdf',
#  'MyBazaar.gsheet',
#  'Netflix_Project']

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Netflix_Project/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["country"].head(10)
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                                  NaN
# 3                                                  NaN
# 4                                                India
# 5                                                  NaN
# 6                                                  NaN
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object

# %%
df["country"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipykernel_763/2610528027.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["country"].fillna("Unknown",inplace=True)

# %%
df["country"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["date_added"] = df["date_added"].str.strip()

# %%
df["date_added"]=pd.to_datetime(df["date_added"])

# %%
df["date_added"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["date_added"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipykernel_763/1401401757.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["date_added"].fillna("Unknown",inplace=True)
# /tmp/ipykernel_763/1401401757.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df["date_added"].fillna("Unknown",inplace=True)

# %%
df["rating"].fillna("Unknown",inplace=True)
df["duration"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipykernel_763/3284865693.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["rating"].fillna("Unknown",inplace=True)
# /tmp/ipykernel_763/3284865693.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df["cast"].fillna("Unknown",inplace=True)

# %%
df["director"].fillna("Unknown",inplace=True)
# Out:
# /tmp/ipykernel_763/179755989.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["director"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# Unknown        7
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
df["rating"] = df["rating"].replace(["66 min","74 min","84 min"],"Unknown")

# %%
df["release_year"].value_counts().head(10)
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: count, dtype: int64

# %%
df.groupby("release_year")["type"].value_counts()
# Out:
# release_year  type
# 1925          TV Show      1
# 1942          Movie        2
# 1943          Movie        3
# 1944          Movie        3
# 1945          Movie        3
#                         ...
# 2019          TV Show    397
# 2020          Movie      517
#               TV Show    436
# 2021          TV Show    315
#               Movie      277
# Name: count, Length: 119, dtype: int64

# %%
df.groupby(["release_year","type"]).size().unstack()
# Out:
# type          Movie  TV Show
# release_year
# 1925            NaN      1.0
# 1942            2.0      NaN
# 1943            3.0      NaN
# 1944            3.0      NaN
# 1945            3.0      1.0
# ...             ...      ...
# 2017          767.0    265.0
# 2018          767.0    380.0
# 2019          633.0    397.0
# 2020          517.0    436.0
# 2021          277.0    315.0
#
# [74 rows x 2 columns]

# %%
df["listed_in"].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["type"].value_counts().plot(kind="bar")
plt.title("Netflix Content: Movies vs TV Shows")
plt.xlabel("type")
plt.ylabel("Count")
plt.show()

# %%
df["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Countries with the Most Content")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# Unknown        7
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["rating"].value_counts().plot(kind="bar")
plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
trend=df.groupby(["release_year","type"]).size().unstack()

# %%
df["listed_in"].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["listed_in"].value_counts().head(10).plot(kind="bar")

plt.title("Top Netflix Genres (Combinations)")
plt.xlabel("Genres")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
df["release_year"].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
import matplotlib.pyplot as plt

df["release_year"].value_counts().sort_index().plot(kind="line", figsize=(10,5))

plt.title("Netflix Content Over Time")
plt.xlabel("Year")
plt.ylabel("Count")

plt.show()
